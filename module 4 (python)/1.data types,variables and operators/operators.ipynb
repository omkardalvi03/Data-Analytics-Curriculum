# %%
# numeric types and arithmetic operators

#integer
a=10

# float
b=3.5

# complex number
c= 2+ 3j

# addition
add= a+ b
sub = a-b
divide = a/b
exp = a**b

print(add)
print(sub)
print(divide)
print(exp)
# Out:
# 13.5
# 6.5
# 2.857142857142857
# 3162.2776601683795

# %%
# sequence type and indexing 

#create a list
lst= ['apple','banna','orange']

a= lst[0]
b= lst[1]
c= lst[2]

print(a)
print(b)
print(c)

d = "grapes"
lst.append(d)
lst

lst.remove('apple')
lst
# Out:
# apple
# banna
# orange
# ['banna', 'orange', 'grapes']

# %%
# string manipulation and comparison

# string concatenation
name = "Aryan"
greeting = "hello"
string = greeting + " " + name
print(string)

# string indexing
first_letter = string[0]
print(first_letter)

sliced_name= string[6:]
print(sliced_name)
# Out:
# hello Aryan
# h
# Aryan

# %%
# boolean logic and logical operators

#boolean variables
is_sunny = True
is_raining= False
is_sunny and is_raining
# Out:
# False
