# %%
import pandas as pd
titanic=pd.read_csv('train.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# find the top 5 rows of your data
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
titanic.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
#drop duplicates

titanic.drop_duplicates(inplace=True)
titanic.reset_index(inplace=True, drop=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Checking for Null values
null_counts = titanic.isnull().sum()
if null_counts.sum() > 0:
    print("Missing values per column:")
    print(null_counts[null_counts > 0])
# Out:
# Missing values per column:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %%
687/891
# Out:
# 0.7710437710437711

# %% [markdown]
# ## Data Cleaning & Missing Value Handling

# %%
# If the number of entries is N, you have less than 5-10% missing values-- we can eliminate those rows

titanic= titanic[titanic.Embarked.notna()]

# If the number of entries is N, you have 30-50% missing values-- we can replace the rows with mean, median, mode
titanic['Age'].fillna(titanic['Age'].median(), inplace=True)


#If the number of entries is N, you have above 70% missing values-- Use some intuition and eliminate the column

titanic= titanic.drop('Cabin', axis=1)

titanic.drop_duplicates(inplace=True)
titanic.reset_index(inplace=True, drop=True)
titanic
# Out:
# C:\Users\omkar\AppData\Local\Temp\ipykernel_5200\582871014.py:6: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   titanic['Age'].fillna(titanic['Age'].median(), inplace=True)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# ...

# %%
#check columns
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='str')

# %%
# check datatypes
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Embarked           str
# dtype: object

# %%
import seaborn as sns
sns.boxplot(titanic['Parch'])
# Out:
# <Axes: ylabel='Parch'>

# %%
titanic= titanic[titanic.Fare<500]
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          887         0       2
# 885          888         1       1
# 886          889         0       3
# 887          890         1       1
# 888          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np
z_scores = np.abs((titanic[['Age', 'SibSp']] - titanic[['Age', 'SibSp']].mean()) / titanic[['Age', 'SibSp']].std())

# Detect outliers using a z-score threshold of 3
outlier_threshold = 3
outliers = titanic[(z_scores['Age'] > outlier_threshold) | (z_scores['SibSp'] > outlier_threshold)]

print("Outliers:")
print(outliers)
# Out:
# Outliers:
#      PassengerId  Survived  Pclass                                     Name  \
# 16            17         0       3                     Rice, Master. Eugene
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# 67            69         1       3          Andersson, Miss. Erna Alexandra
# 70            72         0       3               Goodwin, Miss. Lillian Amy
# 118          120         0       3        Andersson, Miss. Ellis Anna Maria
# 158          160         0       3               Sage, Master. Thomas Henry
# 163          165         0       3             Panula, Master. Eino Viljami
# 170          172         0       3                     Rice, Master. Arthur
# 179          181         0       3             Sage, Miss. Constance Gladys
# 181          183         0       3    Asplund, Master. Clarence Gustaf Hugo
# ...

# %%
# Winsorize the outliers by replacing them with the 95th percentile value
age_threshold = titanic['Age'].quantile(0.95)
SibSp_threshold = titanic['SibSp'].quantile(0.95)
titanic['Age'] = np.where(titanic['Age'] > age_threshold, age_threshold, titanic['Age'])
titanic['SibSp'] = np.where(titanic['SibSp'] > SibSp_threshold, SibSp_threshold, titanic['SibSp'])

# %%
# drop columns
titanic.drop(['PassengerId', 'Name', 'Ticket'], axis=1, inplace=True)

# %%
#group by

gk= titanic.groupby('Survived').mean(numeric_only=True)
gk
# Out:
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.176887  0.444444  0.329690  22.117887
# 1         1.964392  27.914632  0.471810  0.468843  44.077869

# %%
#filtering

female_passengers = titanic[titanic['Sex'] == 'female']
female_passengers
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 1           1       1  female  38.0    1.0      0  71.2833        C
# 2           1       3  female  26.0    0.0      0   7.9250        S
# 3           1       1  female  35.0    1.0      0  53.1000        S
# 8           1       3  female  27.0    0.0      2  11.1333        S
# 9           1       2  female  14.0    1.0      0  30.0708        C
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 878         1       2  female  25.0    0.0      1  26.0000        S
# 880         0       3  female  22.0    0.0      0  10.5167        S
# 883         0       3  female  39.0    0.0      5  29.1250        Q
# 885         1       1  female  19.0    0.0      0  30.0000        S
# 886         0       3  female   NaN    1.0      2  23.4500        S
#
# [311 rows x 8 columns]

# %%
# Visualizations
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.histplot(data=titanic, x='Age', hue='Survived', bins=30, kde=True)
plt.title('Distribution of Passengers by Age and Survival')
plt.show()

plt.figure(figsize=(8, 6))
sns.countplot(data=titanic, x='Pclass', hue='Survived')
plt.title('Count of Passengers by Cabin Class and Survival')
plt.show()
